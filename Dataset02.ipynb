# %% [markdown]
# ### Universidade Federal do Ceará (Centro de Ciências)
# #### CK0223 – Mineração de Dados - 2021.2
# **Aluno:** **Francisco Luan Rodrigues De Sousa, matrícula - 471459**
#
#
# **Professor:** **Dr. José Maria**

# %% [markdown]
# ### Trabalho 2: Análise Estatística e Exploratória dos Dados

# %%
#Importabdo as bibliotecas:

import numpy as np
import pandas as pd
import seaborn as sns
import csv
import matplotlib.pyplot as plt

# %%
#Dataset do primeiro trabalho de mineração de dados com os dados dos maiores Estados do brasil que são icentivadores e o ano deles que foi scrapitado do site do Ministério da Cultura. 

df = pd.read_csv('icentivadores.csv', sep = ';', index_col = [0])

# %%
df
# Out:
#           RESUMO  1993  1994   1995     1996     1997     1998     1999  \
# 0         FISICA   0.0  24.0  181.0    1.438     1.79    1.867    3.531
# 1   Centro Oeste   0.0   0.0    2.0   52.000    18.00   27.000   92.000
# 2       Nordeste   0.0   0.0    0.0   21.000    23.00   37.000   60.000
# 3          Norte   0.0   0.0    0.0    1.000     0.00   17.000   30.000
# 4        Sudeste   0.0   0.0   31.0  503.000   974.00    1.322    1.659
# 5            Sul   0.0  24.0  148.0  861.000   775.00  464.000    1.690
# 6       JURIDICA   2.0  19.0   69.0  732.000  1123.00    1.065    1.249
# 7   Centro Oeste   1.0   1.0    7.0   37.000    39.00   53.000   67.000
# 8       Nordeste   0.0   0.0    2.0   42.000    76.00   44.000   72.000
# 9          Norte   0.0   0.0    0.0    4.000     3.00  300.000   11.000
# 10       Sudeste   1.0  15.0   44.0  443.000   789.00  742.000  812.000
# 11           Sul   0.0   3.0   16.0  206.000   216.00  196.000  287.000
# ...

# %%
 df.dtypes
# Out:
# RESUMO     object
# 1993      float64
# 1994      float64
# 1995      float64
# 1996      float64
# 1997      float64
# 1998      float64
# 1999      float64
# 2000      float64
# 2001      float64
# 2002      float64
# 2003      float64
# 2004      float64
# 2005      float64
# 2006      float64
# 2007      float64
# 2008      float64
# 2009      float64
# 2010      float64
# 2011      float64
# 2012      float64
# 2013      float64
# 2014      float64
# 2015      float64
# 2016      float64
# 2017      float64
# 2018        int64
# 2019      float64
# 2020      float64
# 2021        int64
# Total     float64
# dtype: object

# %%
#Preferi remover uma linha completa(12) que era as conatgens total de cada coluna, isso iria atrapalhar com a análise estatística. 

df = df.drop(index = 12)

# %%
df
# Out:
#           RESUMO  1993  1994   1995     1996     1997     1998     1999  \
# 0         FISICA   0.0  24.0  181.0    1.438     1.79    1.867    3.531
# 1   Centro Oeste   0.0   0.0    2.0   52.000    18.00   27.000   92.000
# 2       Nordeste   0.0   0.0    0.0   21.000    23.00   37.000   60.000
# 3          Norte   0.0   0.0    0.0    1.000     0.00   17.000   30.000
# 4        Sudeste   0.0   0.0   31.0  503.000   974.00    1.322    1.659
# 5            Sul   0.0  24.0  148.0  861.000   775.00  464.000    1.690
# 6       JURIDICA   2.0  19.0   69.0  732.000  1123.00    1.065    1.249
# 7   Centro Oeste   1.0   1.0    7.0   37.000    39.00   53.000   67.000
# 8       Nordeste   0.0   0.0    2.0   42.000    76.00   44.000   72.000
# 9          Norte   0.0   0.0    0.0    4.000     3.00  300.000   11.000
# 10       Sudeste   1.0  15.0   44.0  443.000   789.00  742.000  812.000
# 11           Sul   0.0   3.0   16.0  206.000   216.00  196.000  287.000
#
# ...

# %%
#a) Medidas de Tendência Central de 1993, 2003,2013 e 2021
#Média
#Mediana

# %%
media = df.mean()
media
# Out:
# 1993          0.333333
# 1994          7.166667
# 1995         41.666667
# 1996        241.953167
# 1997        336.482500
# 1998        157.021167
# 1999        119.927417
# 2000        115.274000
# 2001        101.713583
# 2002        111.824000
# 2003        192.111417
# 2004         73.739583
# 2005         80.380750
# 2006         80.620167
# 2007        100.983750
# 2008        174.618833
# 2009        103.796750
# 2010        120.096750
# 2011        135.238500
# 2012        135.503667
# 2013         57.258917
# 2014        131.063000
# 2015         85.625750
# 2016         67.791000
# 2017        148.283417
# 2018     103988.500000
# 2019        142.191250
# 2020        115.720750
# 2021     264514.250000
# Total     43027.680000
# dtype: float64

# %%
mediana = df.median()
mediana
# Out:
# 1993         0.0000
# 1994         0.5000
# 1995        11.5000
# 1996        47.0000
# 1997        57.5000
# 1998        40.5000
# 1999        45.0000
# 2000        19.0000
# 2001        15.5000
# 2002        21.0000
# 2003        43.0000
# 2004        17.5000
# 2005        13.5000
# 2006         9.9295
# 2007         9.4045
# 2008        28.1495
# 2009        11.7040
# 2010        15.3635
# 2011        12.9775
# 2012        13.3260
# 2013        13.9585
# 2014        36.3225
# 2015        10.6600
# 2016        10.6900
# 2017        30.3610
# 2018     11839.5000
# 2019        43.2475
# 2020        36.4530
# 2021     61000.0000
# Total    14982.0000
# dtype: float64

# %%
#Variança
#Desvio Padrão
#Quartis
##Intervalo Interquartil

# %%
Varianca = df.var()
Varianca
# Out:
# 1993     4.242424e-01
# 1994     1.028788e+02
# 1995     3.800242e+03
# 1996     9.751273e+04
# 1997     1.935567e+05
# 1998     5.504969e+04
# 1999     5.380906e+04
# 2000     6.330855e+04
# 2001     4.793254e+04
# 2002     5.960229e+04
# 2003     1.026082e+05
# 2004     1.979569e+04
# 2005     2.562976e+04
# 2006     2.326500e+04
# 2007     3.377558e+04
# 2008     8.382642e+04
# 2009     3.519902e+04
# 2010     5.803162e+04
# 2011     7.490144e+04
# 2012     7.557368e+04
# 2013     5.210945e+03
# 2014     5.482481e+04
# 2015     2.031918e+04
# 2016     1.027899e+04
# 2017     6.773965e+04
# 2018     3.189870e+10
# 2019     4.160557e+04
# 2020     2.365266e+04
# 2021     1.247544e+11
# Total    4.899504e+09
# dtype: float64

# %%
Desvio = df.std()
Desvio
# Out:
# 1993          0.651339
# 1994         10.142918
# 1995         61.646106
# 1996        312.270286
# 1997        439.950775
# 1998        234.626707
# 1999        231.967790
# 2000        251.611896
# 2001        218.935016
# 2002        244.135807
# 2003        320.325141
# 2004        140.697160
# 2005        160.092966
# 2006        152.528671
# 2007        183.781342
# 2008        289.527932
# 2009        187.614009
# 2010        240.897538
# 2011        273.681282
# 2012        274.906681
# 2013         72.186878
# 2014        234.146986
# 2015        142.545360
# 2016        101.385372
# 2017        260.268418
# 2018     178602.060707
# 2019        203.974442
# 2020        153.794219
# 2021     353205.925865
# Total     69996.456578
# dtype: float64

# %%
Quartis1 = df.quantile(0.25)
Quartis2 = df.quantile(0.5)
Quartis3 = df.quantile(0.75)
print('Primeiro quartil:', Quartis1)
print('Segundo quartil:', Quartis2)
print('Terceiro quartil:', Quartis3)
# Out:
# Primeiro quartil: 1993         0.00000
# 1994         0.00000
# 1995         1.50000
# 1996        16.75000
# 1997        14.25000
# 1998        13.21675
# 1999         3.07075
# 2000         2.63875
# 2001         2.84300
# 2002         2.77600
# 2003         2.73150
# 2004         2.20125
# 2005         1.99400
# 2006         2.47450
# 2007         2.27475
# 2008         3.45000
# 2009         2.27250
# 2010         3.01375
# 2011         2.55200
# 2012         2.81850
# 2013         3.04975
# 2014         3.07675
# 2015         1.71725
# 2016         1.54675
# 2017         2.95150
# 2018      2023.25000
# 2019         3.62850
# 2020         3.16575
# 2021     32250.00000
# Total     2239.50000
# Name: 0.25, dtype: float64
# Segundo quartil: 1993         0.0000
# 1994         0.5000
# 1995        11.5000
# 1996        47.0000
# 1997        57.5000
# 1998        40.5000
# 1999        45.0000
# 2000        19.0000
# 2001        15.5000
# 2002        21.0000
# 2003        43.0000
# ...

# %%
IQR = Quartis3-Quartis1
print('Intervalo interquartil:', IQR)
# Out:
# Intervalo interquartil: 1993          0.25000
# 1994         16.00000
# 1995         48.75000
# 1996        441.25000
# 1997        764.25000
# 1998        208.78325
# 1999         73.92925
# 2000         72.61125
# 2001         54.40700
# 2002         60.22400
# 2003        144.26850
# 2004         73.29875
# 2005         87.75600
# 2006         93.52550
# 2007        121.97525
# 2008        171.30000
# 2009        117.72750
# 2010        119.23625
# 2011        152.69800
# 2012        155.68150
# 2013        108.70025
# 2014        147.42325
# 2015        124.03275
# 2016         92.45325
# 2017        141.54850
# 2018     118476.75000
# 2019        189.87150
# 2020        202.33425
# 2021     359000.00000
# Total     35750.75000
# dtype: float64

# %%
#Boxplot e Histograma

# %%
sns.boxplot(df['1993'])
plt.show()

sns.boxplot(df['1994'])
plt.show()


sns.boxplot(df['1995'])
plt.show()

sns.boxplot(df['1996'])
plt.show()

sns.boxplot(df['1997'])
plt.show()

sns.boxplot(df['1999'])
plt.show()

sns.boxplot(df['2003'])
plt.show()

sns.boxplot(df['2006'])
plt.show()

sns.boxplot(df['2009'])
plt.show()

sns.boxplot(df['2012'])
plt.show()

sns.boxplot(df['2015'])
plt.show()

sns.boxplot(df['2018'])
plt.show()

sns.boxplot(df['2021'])
plt.show()
# Out:
# C:\Users\Luan Sousa\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Luan Sousa\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Luan Sousa\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.distplot(df['1993'])
plt.show()

sns.distplot(df['1994'])
plt.show()


sns.distplot(df['1995'])
plt.show()

sns.distplot(df['1996'])
plt.show()

sns.distplot(df['1997'])
plt.show()

sns.distplot(df['1999'])
plt.show()

sns.distplot(df['2003'])
plt.show()

sns.distplot(df['2006'])
plt.show()

sns.distplot(df['2009'])
plt.show()

sns.distplot(df['2012'])
plt.show()

sns.distplot(df['2015'])
plt.show()

sns.distplot(df['2018'])
plt.show()

sns.distplot(df['2021'])
plt.show()
# Out:
# C:\Users\Luan Sousa\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Luan Sousa\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Assimetria
#Curtose
#Correlações

# %%
Assimetria = df.skew()
Assimetria
# Out:
# 1993     1.930090
# 1994     0.957845
# 1995     1.641966
# 1996     1.093268
# 1997     0.898174
# 1998     1.786741
# 1999     2.858561
# 2000     2.914630
# 2001     2.814481
# 2002     2.887277
# 2003     1.761081
# 2004     2.970081
# 2005     2.966322
# 2006     2.788064
# 2007     2.481193
# 2008     1.849658
# 2009     2.439263
# 2010     2.910928
# 2011     2.961014
# 2012     2.950183
# 2013     1.070556
# 2014     2.712889
# 2015     2.266553
# 2016     1.749395
# 2017     2.422823
# 2018     2.348275
# 2019     1.449468
# 2020     1.245610
# 2021     1.213798
# Total    2.172765
# dtype: float64

# %%
Curtose = df.kurtosis()
Curtose
# Out:
# 1993     3.165306
# 1994    -1.032866
# 1995     1.653303
# 1996    -0.258675
# 1997    -1.101311
# 1998     2.690854
# 1999     8.548715
# 2000     8.805418
# 2001     8.131237
# 2002     8.601291
# 2003     1.701893
# 2004     9.432517
# 2005     9.367247
# 2006     8.353141
# 2007     6.606684
# 2008     2.270817
# 2009     6.283679
# 2010     9.022444
# 2011     9.340917
# 2012     9.278069
# 2013    -0.151219
# 2014     8.011022
# 2015     5.514505
# 2016     2.646562
# 2017     6.141461
# 2018     5.814802
# 2019     0.775054
# 2020     0.423028
# 2021    -0.267277
# Total    4.346718
# dtype: float64

# %%
correlation = df.corr()
correlation
# Out:
#            1993      1994      1995      1996      1997      1998      1999  \
# 1993   1.000000  0.348602  0.050565  0.436318  0.548223  0.100560  0.241752
# 1994   0.348602  1.000000  0.921588  0.605572  0.480063  0.361689  0.113723
# 1995   0.050565  0.921588  1.000000  0.453584  0.312056  0.169142 -0.113287
# 1996   0.436318  0.605572  0.453584  1.000000  0.927972  0.398715  0.107261
# 1997   0.548223  0.480063  0.312056  0.927972  1.000000  0.320124  0.208362
# 1998   0.100560  0.361689  0.169142  0.398715  0.320124  1.000000  0.749660
# 1999   0.241752  0.113723 -0.113287  0.107261  0.208362  0.749660  1.000000
# 2000   0.269908  0.150615 -0.076363  0.140861  0.244805  0.771493  0.994752
# 2001   0.255316  0.144874 -0.079766  0.138828  0.239763  0.768039  0.993820
# 2002   0.262000  0.150026 -0.076116  0.141921  0.244745  0.772042  0.995219
# 2003   0.065032  0.500857  0.346000  0.577293  0.412633  0.895761  0.634013
# ...

# %%
#Heatmap
#Best Fit Distribution 
#Gráficos de linha
#Gráficos de barras
#Scartteplots

# %%
plot = sns.heatmap(correlation, annot = False, fmt=".1f", linewidths=.6)
plt.show()

# %%
from fitter import Fitter, get_common_distributions, get_distributions

# %%
data = df.values

# %%
f = Fitter(1993,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#          sumsquare_error        aic       bic  kl_div
# burr         9946.301981  244.98576  9.204956     inf
# beta        10000.000000        inf  9.210340     NaN
# lognorm     10000.000000        inf  9.210340     inf
# norm                 NaN        NaN       NaN     NaN
# gamma                NaN        NaN       NaN     NaN

# %%
f = Fitter(2003,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#          sumsquare_error        aic       bic  kl_div
# burr         9971.759449  385.49205  9.207512     inf
# beta        10000.000000        inf  9.210340     NaN
# lognorm     10000.000000        inf  9.210340     inf
# norm                 NaN        NaN       NaN     NaN
# gamma                NaN        NaN       NaN     NaN

# %%
f = Fitter(2013,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#          sumsquare_error         aic       bic  kl_div
# burr         9638.344118  676.773023  9.173505     inf
# beta        10000.000000         inf  9.210340     NaN
# lognorm     10000.000000         inf  9.210340     inf
# norm                 NaN         NaN       NaN     NaN
# gamma                NaN         NaN       NaN     NaN

# %%
f = Fitter(2021,
           distributions=['gamma',
                          'lognorm',
                          "beta",
                          "burr",
                          "norm"])
f.fit()
f.summary()
# Out:
#          sumsquare_error       aic       bic  kl_div
# burr          9770.77676  203.6361  9.187151     inf
# beta         10000.00000       inf  9.210340     NaN
# lognorm      10000.00000       inf  9.210340     inf
# gamma                NaN       NaN       NaN     NaN
# norm                 NaN       NaN       NaN     NaN

# %%
df.drop(['RESUMO'], axis=1).plot.line(title='Dataset dos projetos')
plt.show()

# %%
df.plot.hist(subplots=True, layout=(3,10), figsize=(15, 10), bins=20)
plt.show()

# %%
sns.pairplot(data = df, vars=['1993','2003','2013', '2021'])
plt.show()
